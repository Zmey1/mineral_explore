# %% [markdown]
# Merge different datasets into a single one

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
aluminum = pd.read_csv('aluminum.csv')
baryte = pd.read_csv('baryte.csv')
diamond = pd.read_csv('diamond.csv')
gold = pd.read_csv('gold_new.csv')
iron = pd.read_csv('Iron.csv')
lead_zinc = pd.read_csv('lead-zinc.csv')
Manganese = pd.read_csv('Manganese.csv')

aluminum['Element'] = 'Aluminum'
baryte['Element'] = 'Baryte'
diamond['Element'] = 'Diamond'
gold['Element'] = 'Gold'
iron['Element'] = 'Iron'
lead_zinc['Element'] = 'Lead-Zinc'
Manganese['Element'] = 'Manganese'

combined_data = pd.concat([aluminum, baryte, diamond, gold, iron, lead_zinc, Manganese], ignore_index=True)

# %% [markdown]
# Adding an Element column to keep track of different kinds of deposits

# %%
combined_data.head()
columns = ['Element'] + [col for col in combined_data.columns if col != 'Element']
combined_data = combined_data[columns]
combined_data.head()
# Out:
#     Element METALLOGENIC PROVINCE        LOCALITY           STATE TOPOSHEET  \
# 0  Aluminum   EAST COAST PROVINCE           ARAKU          ORISSA      65 J
# 1  Aluminum   EAST COAST PROVINCE  KARNAPODIKONDA  ANDHRA PRADESH      65 N
# 2  Aluminum   EAST COAST PROVINCE        SIJIMALI          ORISSA      65 M
# 3  Aluminum   EAST COAST PROVINCE    PANCHPATMALI          ORISSA  65 J & N
# 4  Aluminum   EAST COAST PROVINCE         ANAMINI          ORISSA      65 M
#
#        LATITUDE     LONGITUDE COMMODITY                        HOSTROCK  \
# 0  18 16-18 22N  82 56-82 59E   Bauxite           CAPPING ON KHONDALITE
# 1        18 48N        83 05E   Bauxite   CAPPING ON GRANULITE/GNEISSES
# 2        19 30N        83 08E   Bauxite  CAPPING ON KHONDALITE/GNEISSES
# 3  18 46-18 55N  82 57-83 04E   Bauxite           CAPPING ON KHONDALITE
# 4        19 51N        83 40E   Bauxite           CAPPING ON KHONDALITE
#
#       MORPHOGENESIS          FORMATION METALLOGENESIS  LATDD  LONDD
# 0  RESIDUAL DEPOSIT  EASTERN GHAT Sgp.            NaN    NaN    NaN
# 1  RESIDUAL DEPOSIT  EASTERN GHAT Sgp.            NaN    NaN    NaN
# 2  RESIDUAL DEPOSIT  EASTERN GHAT Sgp.            NaN    NaN    NaN
# 3  RESIDUAL DEPOSIT  EASTERN GHAT Sgp.            NaN    NaN    NaN
# 4  RESIDUAL DEPOSIT  EASTERN GHAT Sgp.            NaN    NaN    NaN

# %%
combined_data.drop(columns=['Element'])
# Out:
#     METALLOGENIC PROVINCE           LOCALITY           STATE TOPOSHEET  \
# 0     EAST COAST PROVINCE              ARAKU          ORISSA      65 J
# 1     EAST COAST PROVINCE     KARNAPODIKONDA  ANDHRA PRADESH      65 N
# 2     EAST COAST PROVINCE           SIJIMALI          ORISSA      65 M
# 3     EAST COAST PROVINCE       PANCHPATMALI          ORISSA  65 J & N
# 4     EAST COAST PROVINCE            ANAMINI          ORISSA      65 M
# ..                    ...                ...             ...       ...
# 256                   NaN               UKWA  MADHYA PRADESH      64 C
# 257                   NaN  LAUGHAR-KAMHATOLA  MADHYA PRADESH      64 C
# 258                   NaN              ANMOD             GOA      48 I
# 259                   NaN         HATTIKAMBA       KARNATAKA      48 I
# 260                   NaN      TERALI-BISGOD             GOA      48 I
#
#          LATITUDE     LONGITUDE  COMMODITY  \
# 0    18 16-18 22N  82 56-82 59E    Bauxite
# 1          18 48N        83 05E    Bauxite
# 2          19 30N        83 08E    Bauxite
# 3    18 46-18 55N  82 57-83 04E    Bauxite
# 4          19 51N        83 40E    Bauxite
# ..            ...           ...        ...
# 256        21 58N        80 28E  Manganese
# 257        21 50N        80 22E  Manganese
# 258        15 26N        74 18E  Manganese
# 259        15 16N        74 27E  Manganese
# 260        15 10N        74 22E  Manganese
#
#                                      HOSTROCK          MORPHOGENESIS  \
# 0                       CAPPING ON KHONDALITE       RESIDUAL DEPOSIT
# 1               CAPPING ON GRANULITE/GNEISSES       RESIDUAL DEPOSIT
# 2              CAPPING ON KHONDALITE/GNEISSES       RESIDUAL DEPOSIT
# 3                       CAPPING ON KHONDALITE       RESIDUAL DEPOSIT
# 4                       CAPPING ON KHONDALITE       RESIDUAL DEPOSIT
# ..                                        ...                    ...
# 256                       SCHIST AND PHYLLITE     CONCORDANT-TABULAR
# 257                                   SCHISTS             CONCORDANT
# 258       LATERITE ON VOLCANICS OF GREENSTONE  VOLCANOGENIC-ENRICHED
# 259   LATERITE ON VOLCANOSEDIMENTARY SEQUENCE   SUPERGENE ENRICHMENT
# 260  LATERITE ON VOLCANOSEDIMETS OF GREENSTON   SUPERGENE ENRICHMENT
#
#                  FORMATION    METALLOGENESIS      LATDD
# 0        EASTERN GHAT Sgp.               NaN        NaN
# 1        EASTERN GHAT Sgp.               NaN        NaN
# 2        EASTERN GHAT Sgp.               NaN        NaN
# 3        EASTERN GHAT Sgp.               NaN        NaN
# 4        EASTERN GHAT Sgp.               NaN        NaN
# ..                     ...               ...        ...
# 256            LOHANGI Fm.       SAUSAR BELT  21.966667
# 257           LOHANGI Fm..       SAUSAR BELT  21.833333
# 258   CHITRADURGA BELT Gp.  SHIMOGA-GOA BELT  15.433333
# 259   CHITRADURGA BELT Gp.  SHIMOGA-GOA BELT  15.266667
# 260  CHITRADURGA BELT BELT  SHIMOGA-GOA BELT  15.166667
#
# [261 rows x 12 columns]

# %% [markdown]
# Saving V1 dataset

# %%
combined_data.to_csv('combined_data.csv', index=False)

# %% [markdown]
# Converting Latitude and Longitude into Decimal Degrees
#
# Try 1:

# %%
import pandas as pd
import re

# Function to convert DMS (Degrees, Minutes, Seconds) to Decimal Degrees (DD)
def dms_to_dd(dms):
    # Regex to extract degrees, minutes, and seconds
    match = re.match(r"(\d+)[° ](\d+)?[\' -]?(\d+)?[\" -]?[NSEW]", dms, re.IGNORECASE)
    if not match:
        return None
    degrees = int(match.group(1))
    minutes = int(match.group(2)) if match.group(2) else 0
    seconds = int(match.group(3)) if match.group(3) else 0
    
    # Convert to decimal degrees
    dd = degrees + (minutes / 60) + (seconds / 3600)
    
    # Handle direction (N, S, E, W)
    if 'S' in dms or 'W' in dms:
        dd = -dd
    return dd

# Function to clean and standardize DMS entries
def clean_dms(dms):
    # Normalize spacing and separators
    dms = re.sub(r'[^\dNSEW°\'"]+', ' ', str(dms))
    dms = re.sub(r'\s+', ' ', dms).strip()
    return dms

# Load the dataset
file_path = 'combined_data.csv'
combined_data = pd.read_csv(file_path)

# Clean LATITUDE and LONGITUDE columns
combined_data['LATITUDE'] = combined_data['LATITUDE'].apply(clean_dms)
combined_data['LONGITUDE'] = combined_data['LONGITUDE'].apply(clean_dms)

# Convert to Decimal Degrees
combined_data['LATDD'] = combined_data['LATITUDE'].apply(lambda x: dms_to_dd(x))
combined_data['LONDD'] = combined_data['LONGITUDE'].apply(lambda x: dms_to_dd(x))

# %% [markdown]
# Saving Dataset after converting V2

# %%
# Save the cleaned dataset
output_path = 'cleaned_combined_data.csv'
combined_data.to_csv(output_path, index=False)

# %%
cleaned_combined_data = pd.read_csv('cleaned_combined_data.csv')

# %%
cleaned_combined_data['METALLOGENESIS'].isnull().sum()
# Out:
# 49

# %% [markdown]
# Combing METALLOGENESIS and METALLOGENIC PROVINCE columns into one and dropping METALLOGENIC PROVINCE

# %%
cleaned_combined_data.loc[:48, 'METALLOGENESIS'] = cleaned_combined_data.loc[:48, 'METALLOGENESIS'].fillna(cleaned_combined_data.loc[:48, 'METALLOGENIC PROVINCE'])

# %%
cleaned_combined_data = cleaned_combined_data.drop(columns=['METALLOGENIC PROVINCE'],errors='IGNORE')

# %%
cleaned_combined_data.to_csv('cleaned_combined_data.csv', index=False)

# %% [markdown]
# Temp conversion of lat long to Decimal Degrees
#
# Try 2

# %%
import pandas as pd
import re

# Function to reprocess DMS (Degrees, Minutes, Seconds) to Decimal Degrees (DD)
def dms_to_dd(dms):
    if pd.isnull(dms) or not isinstance(dms, str):
        return None
    # Regex to extract degrees, minutes, and seconds
    match = re.match(r"(\d+)[° ](\d+)?[\' -]?(\d+)?[\" -]?[NSEW]", dms, re.IGNORECASE)
    if not match:
        return None
    degrees = int(match.group(1))
    minutes = int(match.group(2)) if match.group(2) else 0
    seconds = int(match.group(3)) if match.group(3) else 0
    
    # Convert to decimal degrees
    dd = degrees + (minutes / 60) + (seconds / 3600)
    
    # Handle direction (N, S, E, W)
    if 'S' in dms or 'W' in dms:
        dd = -dd
    return dd

# Load dataset
final_dataset = pd.read_csv('cleaned_combined_data.csv')

# Apply the function to fix missing LATDD and LONDD values
final_dataset['LATDD'] = final_dataset['LATDD'].fillna(
    final_dataset['LATITUDE'].apply(lambda x: dms_to_dd(str(x)))
)
final_dataset['LONDD'] = final_dataset['LONDD'].fillna(
    final_dataset['LONGITUDE'].apply(lambda x: dms_to_dd(str(x)))
)

# Check for duplicate rows and drop them
duplicates = final_dataset.duplicated()
final_dataset = final_dataset[~duplicates]

# Validate data consistency
missing_values = final_dataset.isnull().sum()  # Check for any remaining missing values
unique_elements = final_dataset.nunique()  # Check unique values in each column for consistency

# Save the updated dataset
final_dataset.to_csv('final_combined_data.csv', index=False)
